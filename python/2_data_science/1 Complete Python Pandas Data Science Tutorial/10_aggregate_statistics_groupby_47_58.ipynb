# %%
import pandas as pd
df = pd.read_csv('modified_no_index.csv')
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df.groupby(['Type 1']).mean().head(3)
# Out:
#                  #       Total         HP      Attack    Defense    Sp. Atk  \
# Type 1
# Bug     334.492754  378.927536  56.884058   70.971014  70.724638  53.869565
# Dark    461.354839  445.741935  66.806452   88.387097  70.225806  74.645161
# Dragon  474.375000  550.531250  83.312500  112.125000  86.375000  96.843750
#
#           Sp. Def      Speed  Generation  Legendary
# Type 1
# Bug     64.797101  61.681159    3.217391   0.000000
# Dark    69.516129  76.161290    4.032258   0.064516
# Dragon  88.843750  83.031250    3.875000   0.375000

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False).head(3)
# Out:
#                  #       Total         HP      Attack     Defense    Sp. Atk  \
# Type 1
# Steel   442.851852  487.703704  65.222222   92.703704  126.370370  67.518519
# Rock    392.727273  453.750000  65.363636   92.863636  100.795455  63.340909
# Dragon  474.375000  550.531250  83.312500  112.125000   86.375000  96.843750
#
#           Sp. Def      Speed  Generation  Legendary
# Type 1
# Steel   80.629630  55.259259    3.851852   0.148148
# Rock    75.477273  55.909091    3.454545   0.090909
# Dragon  88.843750  83.031250    3.875000   0.375000

# %%
df.groupby(['Type 1']).sum().head(3)
# Out:
#             #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug     23080  26146  3925    4897     4880     3717     4471   4256
# Dark    14302  13818  2071    2740     2177     2314     2155   2361
# Dragon  15180  17617  2666    3588     2764     3099     2843   2657
#
#         Generation  Legendary
# Type 1
# Bug            222        0.0
# Dark           125        2.0
# Dragon         124       12.0

# %%
df.groupby(['Type 1']).count().head(3)
# Out:
#          #  Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug     69    69      52     69  69      69       69       69       69     69
# Dark    31    31      21     31  31      31       31       31       31     31
# Dragon  32    32      21     32  32      32       32       32       32     32
#
#         Generation  Legendary
# Type 1
# Bug             69         69
# Dark            31         31
# Dragon          32         32

# %%
df['count'] = 1 #Display only one field count.
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df['count'] = 1 #Display only one field count.
df.groupby(['Type 1', 'Type 2']).count()['count'] #Outer-inner grouped counts.
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
