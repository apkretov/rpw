# %%
import numpy as np

# %% [markdown]
# ### numpy.random.randint

# %%
print(np.random.randint(0, 50, 50))
# Out:
# [30 34 38 36  0  3 30 37 10 16 20 12  8  3 35 41 28 33  8 35 44 16  8 13
#  10 48  0 16 39 12 29 20 32 23 10 18 11 42 11  7  6 23  0 32  8  3  6 46
#  18  4]

# %%
print(np.random.randint(50, size=50))
# Out:
# [16 28  8 26  4 45 27  0 28 30 30 45  8 17 18 30 14 47 22 15 23 27 33  5
#  24 15  2 10 14  0 39 39 15 18 48 31  9 41 42 15 39 36  3 27 48 21 36 20
#  39 31]

# %% [markdown]
# ### numpy.random.randn

# %%
print(np.random.randn(50))
# Out:
# [-0.96030691 -0.34495055 -0.90979233 -1.26363193  0.51539371 -0.31625239
#  -0.657511    1.36705108  0.41367592 -0.42813636  0.19333696  0.35554658
#  -1.63838003  1.00542589  0.10860178 -0.63675936  1.32343944  0.3993719
#   1.65633525 -0.87882756  0.62326731  0.63588835  1.02555748 -2.62448887
#   0.90190069 -0.93608296 -0.87861035 -1.39088498 -0.62680273 -0.52581084
#   1.78966471 -1.09013578  1.86745206  0.52068925  0.3893401   1.32772257
#  -0.32242851 -2.40962777  1.0063457  -0.38455653 -1.04388099  1.45258758
#   1.19233872 -1.24130106 -0.97266765 -0.07375648  0.00309285 -0.87668073
#   0.42536419  1.39806617]

# %%
np.random.randn()
# Out:
# -1.1589159337836898

# %%
print(np.random.randn(1))
# Out:
# [-0.51580465]

# %%
print(np.random.randn(2))
# Out:
# [ 1.10669217 -1.04060854]

# %%
print(np.random.randn(3))
# Out:
# [-0.23029481  0.20124686  0.90416096]

# %%
# n = 50
n = 100
# n = 500
data = {'a': np.arange(n),
      'c': np.random.randint(0, n, n),
      'd': np.random.randn(n)}

# print(f"a: {data['a']}")
# print(f"c: {data['c']}")

data['b'] = data['a'] + 10 * np.random.randn(n)
# print(f"b: {data['b']}")

# print(f"\nd: {data['d']}")
# data['d'] = np.abs(data['d']) * 100
data['d'] = np.abs(data['d']) * 300
# print(f"d: {data['d']}")

plt.scatter('a', 'b', c='c', s='d', data=data)
# plt.scatter('a', 'b', c='c', data=data)
# plt.scatter('a', 'b', c='c', data=data, marker='^', s='d')
plt.show()

# %% [markdown]
# ### antialiased

# %%
# What is `antialiased` in `matplotlib.collections` and how do you set the parameter for it? @ https://stackoverflow.com/questions/8750203/what-is-antialiased-in-matplotlib-collections-and-how-do-you-set-the-paramet
# Spatial anti-aliasing @ https://en.wikipedia.org/wiki/Spatial_anti-aliasing
# Сглаживание @ https://ru.wikipedia.org/wiki/%D0%A1%D0%B3%D0%BB%D0%B0%D0%B6%D0%B8%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5

plt.subplot(1,2,1)
plt.plot(range(10), antialiased=False)
plt.title('Antialiasing Off')

plt.subplot(1,2,2)
plt.plot(range(10), antialiased=True)
plt.title('Antialiasing On')

plt.show()
